# %%
# !git clone https://github.com/openvpi/SingingVoice-MFA-Training
# Out:
# Cloning into 'SingingVoice-MFA-Training'...
# remote: Enumerating objects: 285, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 285 (delta 0), reused 3 (delta 0), pack-reused 281
# Receiving objects: 100% (285/285), 56.06 MiB | 30.20 MiB/s, done.
# Resolving deltas: 100% (104/104), done.

# %%
# !pip install -q condacolab
import condacolab
condacolab.install_miniconda()
# Out:
# ⏬ Downloading https://repo.anaconda.com/miniconda/Miniconda3-py37_4.12.0-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:25
# 🔁 Restarting kernel...

# %%
import condacolab
condacolab.check()
# Out:
# ✨🍰✨ Everything looks OK!

# %%
# !conda create -n aligner -c conda-forge montreal-forced-aligner

# %%
# !source activate aligner; \
mfa -h

# %%
# !source activate aligner; \
mfa version
# Out:
# 2.0.6

# %%
#MFA下载已有的声学模型和词典可以用model download
# !source activate aligner; \
mfa model download acoustic english_us_arpa
# Out:
# INFO - Saved model to f/root/Documents/MFA/pretrained_models/acoustic/english_us_arpa.zip, you can now use
#                 english_us_arpa in place of acoustic paths in mfa commands.
# INFO - Saved model to f/root/Documents/MFA/pretrained_models/acoustic/english_us_arpa.zip, you can now use
#                 english_us_arpa in place of acoustic paths in mfa commands.

# %%
#MFA检测现有数据集的错误和词典外的单词 
# !source activate aligner; \
mfa validate /content/SingingVoice-MFA-Training/my_corpus /content/SingingVoice-MFA-Training/my_dictionary.txt

# %%
#MFA训练现有数据集 mfa train --clean <corpus path> <dictionary path> <acoustic model path> <aligned textgrids path>
# !source activate aligner; \
mfa train --clean /content/SingingVoice-MFA-Training/my_corpus /content/SingingVoice-MFA-Training/my_dictionary.txt /content/SingingVoice-MFA-Training/acoustic-model-training/opencpop_acoustic_model.zip /content/SingingVoice-MFA-Training/acoustic-model-training
# Out:
# INFO - Setting up corpus information...
# INFO - Loading corpus from source files...
# 100% 5/5 [00:01<00:00,  4.86it/s]
# INFO - Found 1 speaker across 5 files, average number of utterances per speaker: 5.0
# INFO - Initializing multiprocessing jobs...
# WARNING - Number of jobs was specified as 3, but due to only having 1 speakers, MFA will only use 1 jobs.
# INFO - Creating corpus split for feature generation...
# INFO - Generating base features (mfcc)...
# INFO - Generating MFCCs...
#   0% 0/5 [00:01<?, ?it/s]
# INFO - Calculating CMVN...
# INFO - Creating corpus split with features...
# INFO - Initializing training for monophone...
# INFO - Compiling training graphs...
# 100% 5/5 [00:01<00:00,  4.71it/s]
# INFO - Generating initial alignments...
# 100% 5/5 [00:01<00:00,  4.58it/s]
# INFO - monophone training already initialized, skipping initialization.
# INFO - monophone - Iteration 1 of 40
# INFO - Generating alignments...
# 100% 5/5 [00:01<00:00,  4.05it/s]
# ...

# %%
#MFA利用现有声学模型和词典进行对齐 mfa align <corpus path> <dictionary path> <acoustic model path> <aligned textgrids path>
# !source activate aligner; \
mfa align /content/SingingVoice-MFA-Training/my_corpus /content/SingingVoice-MFA-Training/my_dictionary.txt /content/SingingVoice-MFA-Training/opencpop_acoustic_model.zip /content/SingingVoice-MFA-Training/acoustic-model-applying
# Out:
# INFO - Setting up corpus information...
# INFO - Loading corpus from source files...
# 100% 5/5 [00:01<00:00,  4.86it/s]
# INFO - Found 1 speaker across 5 files, average number of utterances per speaker: 5.0
# INFO - Initializing multiprocessing jobs...
# WARNING - Number of jobs was specified as 3, but due to only having 1 speakers, MFA will only use 1 jobs.
# INFO - Creating corpus split for feature generation...
# INFO - Generating base features (mfcc)...
# INFO - Generating MFCCs...
#   0% 0/5 [00:01<?, ?it/s]
# INFO - Calculating CMVN...
# INFO - Creating corpus split with features...
# INFO - Compiling training graphs...
# 100% 5/5 [00:01<00:00,  4.62it/s]
# INFO - Performing first-pass alignment...
# INFO - Generating alignments...
# 100% 5/5 [00:02<00:00,  1.76it/s]
# INFO - Calculating fMLLR for speaker adaptation...
# 100% 1/1 [00:01<00:00,  1.39s/it]
# INFO - Performing second-pass alignment...
# INFO - Generating alignments...
# 100% 5/5 [00:02<00:00,  1.91it/s]
# ...

# %%
#from google.colab import drive
#drive.mount('/root/drive')

# %%
#bin
#!pip install unrar
#%cd /root/Documents/MFA
#!unrar x "/root/drive/MyDrive/opencpop.rar"

# %%
#!source activate aligner; \
#mfa validate /root/Documents/MFA/opencpop/my_corpus /root/Documents/MFA/opencpop/my_dictionary.txt

# %%
#!source activate aligner; \
#mfa train -j 6 --clean /root/Documents/MFA/opencpop/my_corpus /root/Documents/MFA/opencpop/my_dictionary.txt /root/drive/MyDrive/opencpop_acoustic_model.zip /root/drive/MyDrive/opencpop_aligned

# %%
#!source activate aligner; \
#mfa train --num_jobs 8 --clean --phone_set PINYIN /root/Documents/MFA/opencpop/my_corpus /root/Documents/MFA/opencpop/my_dictionary.txt /root/drive/MyDrive/opencpop_acoustic_model.zip /root/drive/MyDrive/opencpop_aligned
